# %% [markdown]
# ### This is to automatically add the cloze pattern to the cloze field

# %%
import requests
import json
import re

def invoke(action, **params):
    return requests.post(
        "http://localhost:8765",
        json={
            "action": action,
            "version": 6,
            "params": params
        }
    ).json()

# example: get deck names
print(invoke("deckNames"))
# Out:
# {'result': ['Default', 'French MOVIES', 'Japanese Basic Vokab', 'Japanese Heisig', 'Japanese Heisig::All in one Kanji - Heisig order', 'Japanese Heisig::Deck in progress', 'Japanese Heisig::Remembering the Kanji Vol. 1, 4th Editon', 'Japanese Heisig::Remembering the Kanji Vol. 1, 4th Editon::Part 1: Stories (Lessons 1-12)', 'Japanese Heisig::Remembering the Kanji Vol. 1, 4th Editon::Part 2: Plots (Lessons 13-19)', 'Japanese Heisig::Remembering the Kanji Vol. 1, 4th Editon::Part 3: Elements (Lessons 20-56)', 'Japanese Heisig::Remembering the Kanji Vol. 1, 4th Editon::漢字 Outside 1st Volume', 'Japanese KANJI', 'Japanese KANJI::FirstLove', 'Japanese KANJI::LaLaLand', "Japanese KANJI::YUYU's ポッドキャスト", 'Japanese Media', 'Japanese Media::Filme & Serien', 'Japanese Media::Filme & Serien::FirstLove', 'Japanese Media::Filme & Serien::FirstLove::Episode1 Where the Lilacs bloom', 'Japanese Media::Filme & Serien::FirstLove::Episode2', 'Japanese Media::Filme & Serien::FirstLove::Episode3', 'Japanese Media::Filme & Serien::FirstLove::Episode4', 'Japanese Media::Filme & Serien::FirstLove::Episode5 Talk In Sign Language', 'Japanese Media::Filme & Serien::Heat', 'Japanese Media::Filme & Serien::LaLaLand', 'Japanese Media::News', 'Japanese Media::News::ANNnewsCH', 'Japanese Media::News::ANNnewsCH::「最後のチャンス」合意か攻撃か 中東に米軍集結\u3000焦点は“ウラン濃縮度”【報道ステーション】(2026年2月26日)', 'Japanese Media::Youtube', 'Japanese Media::Youtube::BappaShota', 'Japanese Media::Youtube::BappaShota::トルコの空港の奇妙なカプセルホテルに泊まってグルメを食べ歩いてみた', 'Japanese Media::Youtube::BappaShota::ロシアの樹海でトナカイと住む民族との生活がとんでもなかった', 'Japanese Media::Youtube::BappaShota::乗り継ぎ時間に空港の外へ出てイスタンブールをぶらりしてみた', 'Japanese Media::Youtube::BappaShota::亡命チベット人達が集うヒマラヤに住むたった1人の日本人女性を訪れてみた', 'Japanese Media::Youtube::BappaShota::物価規格外アメリカに1万円持って行ったら円の価値なさ過ぎて瞬殺破産...', 'Japanese Media::Youtube::Konnichiwa My Dude Japanese Podcast', 'Japanese Media::Youtube::Konnichiwa My Dude Japanese Podcast::ジブリ愛が止まらない | 日本語ポッドキャスト EP299', 'Japanese Media::Youtube::Konnichiwa My Dude Japanese Podcast::東京スカイツリーで事故発生… | 日本語ポッドキャスト EP297', "Japanese Media::Youtube::YUYU's ポッドキャスト", "Japanese Media::Youtube::YUYU's ポッドキャスト::20代でやっておいた方がいいこと / Things You Should Do While You’re Still Young", "Japanese Media::Youtube::YUYU's ポッドキャスト::Vol.419どうして日本人は謙遜するのか？", "Japanese Media::Youtube::YUYU's ポッドキャスト::Vol.420内向的(introvert)な人間が自分を好きになるまで", 'Japanese Media::Youtube::ジオヒストリー', 'Japanese Media::Youtube::ジオヒストリー::イスラエル・パレスチナ問題', 'Japanese Media::Youtube::ジオヒストリー::サッカーの歴史', 'Japanese Media::Youtube::ジオヒストリー::ビールの歴史', 'Japanese Media::Youtube::ゼロ・ウェイストで面白く暮らす方法とは！？中村修', 'Kanji', 'migaku'], 'error': None}

# %%
#find all the Notes, that I am already learning in the "Japanese Media" deck, so that I can unsuspend their RTK card.
# take care of the fact that there might be more than one note type in this deck!

note_ids = invoke(
    "findNotes",
    query='deck:"Japanese Media::Youtube::Konnichiwa My Dude Japanese Podcast::ジブリ愛が止まらない | 日本語ポッドキャスト EP299"'
)

#get information about those notes, to find the RTK card ids
notes_info = invoke(
    "notesInfo",
    notes=note_ids['result']
)
#DONT FORGET that in this deck are 2 different note types!!!

#field names
print("Fields in each note:")
for note in notes_info['result'][:1]:  # Print only the first note's fields for inspection
    print(list(note['fields'].keys()))
# Out:
# Fields in each note:
# ['Cloze', 'Furigana', 'Pitch Accent', 'Word Definition', 'Translation', 'Context Before Cloze', 'Context After Cloze', 'Context', 'Context Translation', 'Notes', 'Grammatik', 'Item Key', 'Subtitle', 'Lemma', 'Word', 'Part of Speech', 'Color', 'Source', 'Language', 'Translation Language', 'Word Transliteration', 'Phrase Transliteration', 'Subtitle Index', 'Item ID', 'Item Title', 'Date Created', 'Date Modified', 'Prev Image', 'Next Image', 'Audio Clip', 'Kanji', 'Diagram', 'Reading', 'Frequency']

# %% [markdown]
# ### Now we have the note ids and the field names, we can create the cloze deletion and update the notes with the new cloze field.

# %%
import re

def make_cloze(cloze_field, lemma, definition):
    # Skip rows where lemma contains a comma
    if "," in lemma:
        return cloze_field  # or return None if you want to filter later

    return re.sub(
        r"<strong>.*?</strong>",
        f"{{{{c1::{lemma}::{definition}}}}}",
        cloze_field,
        count=1
    )



for note in notes_info["result"]:
    note_id = note["noteId"]

    cloze_field = note["fields"]["Cloze"]["value"]  # adjust to your real field name
    Lemma = note["fields"]["Lemma"]["value"]
    Definition = note["fields"]["Notes"]["value"]  # adjust to your real field name

    new_sentence = make_cloze(cloze_field, Lemma, Definition)

    invoke(
        "updateNoteFields",
        note={
            "id": note_id,
            "fields": {
                "Cloze": new_sentence
            }
        }
    )

# %%
#find any kanji in the "Cloze" field and append them to a list


kanji_list = []

for note in notes_info['result']:
    cloze_field = note['fields']['Cloze']['value']
    # Find all kanji characters in the Cloze field
    kanji_matches = re.findall(r'[\u4e00-\u9fff]', cloze_field)
    for kanji in kanji_matches:
        if kanji not in kanji_list:
            kanji_list.append(kanji)

print("Found Kanji:", kanji_list)
# Out:
# Found Kanji: ['日', '本', '語', '今', '俺', '飲', '病', '人', '痛', '軽', '減', '歩', '散', '行', '恥', '上', '半', '身', '前', '出', '向', '鳥', '方', '中', '誰', '会', '感', '当', '心', '体', '何', '健', '康', '状', '態', '一', '致', '思', '優', '余', '力', '言', '後', '去', '年', '赤', '字', '話', '同', '時', '正', '風', '実', '損', '失', '動', '画', '聞', '最', '見', '基', '的', '世', '界', '集', '大', '変', '番', '組', '目', '調', '朝', '新', '記', '事', '読', '東', '京', '高', '誇', '都', '墨', '田', '区', '月', '夜', '急', '停', '止', '乗', '閉', '込', '消', '防', '警', '察', '救', '助', '完', '了', '午', '過', '計', '間', '分', '頃', '階', '地', '展', '望', '春', '夏', '秋', '冬', '報', '緊', '安', '全', '確', '認', '幸', '約', '点', '子', '供', '含', '男', '女', '低', '現', '考', '特', '作', '業', '隣', '移', '側', '面', '用', '開', '橋', '渡', '法', '施', '知', '起', '機', '械', '常', '怪', '我', '結', '構', '回', '多', '次', '有', '名', '曲', '呪', '術', '戦', '愛', '憎', '題', '僕', '来', '嬉', '近', '炎', '非', '難', '参', '加', '客', '観', '井', '口', '歌', '声', '積', '極', '促', '発', '企', '外', '君', '臨', '校', '楽', '緒', '元', '気', '場', '続', '投', '稿', '拡', '以', '求', '応', '素', '量', '関', '対', '昔', '演', '奏', '者', '音', '立', '内', '容', '理', '解', '再', '生', '数', '伸', '好', '評', '端', '星', '売', '配', '信', '決', '定', '書', '激', '懐', '小', '学', '万', '円', '値', '段', '色', '褪', '初', '品', '緑', '魅', '奈', '良', '島', '追', '冒', '険', '舞', '台', '広', '始', '遅', '草', '予', '遊', '様', '限', '幕', '入', '厳', '長', '録', '税', '待', '価', '格', '別', '版', '節', '欲', '買', '連', '億', '落', '札', '賞', '送', '可', '描', '持', '仕', '戻', '紹', '介', '商', '洗', '濯', '白', '自', '歯', '磨', '短', '両', '苦', '手', '必', '要', '医', '期', '怖', '系', '況', '架', '空', '社', '従', '員', '廃', '墟', '踪', '件', '真', '相', '探', '工', '索', '型', '形', '住', '襲', '根', '検', '討', '戯', '王', '届', '和', '室', '部', '屋', '置', '申', '訳', '告', '毎', '経', '費', '交', '通', '使', '他', '細', '振', '返', '強', '驚', '挑', '土', '柱', '扱', '蔵', '成', '無', '駄', '局', '額', '払', '制', '重', '儲', '徹', '果', '少', '終', '水', '準', '英', '漫', '物', '購', '金', '収', '益', '活', '休', '料', '盛', '西', '引', '越', '週', '普', '頑', '張', '働', '係', '旦', '昨', '原']

# %% [markdown]
# ### Now we need to process the cards, that have several different words in the lemma field!
#
# 1. add 2 new notes with an identical cloze field
# 2. then delete the 2 extra words from the lemma field
# 3. run the make_cloze function on these notes, (capture group needs to be slightly different)

# %% [markdown]
# TODO: automatically add the hiragana as hint
#
# (japanese word instead of keyword?)

# %%
# MULTI-LEMMA PROCESSING (added by Codex)
# Splits notes where Lemma contains commas into multiple notes,
# keeps original Cloze context, and creates lemma-specific clozes.

import re


def split_lemmas(lemma_value):
    return [part.strip() for part in lemma_value.split(',') if part.strip()]


def make_cloze_for_lemma(cloze_field, lemma, definition):
    # Prefer replacing the <strong> tag that contains this exact lemma.
    specific_pattern = re.compile(rf"<strong>\s*{re.escape(lemma)}\s*</strong>")
    replacement = f"{{{{c1::{lemma}::{definition}}}}}"

    if specific_pattern.search(cloze_field):
        return specific_pattern.sub(replacement, cloze_field, count=1)

    # Fallback if exact strong match is not found.
    return re.sub(r"<strong>.*?</strong>", replacement, cloze_field, count=1)


def get_note_fields(note):
    return {name: meta['value'] for name, meta in note['fields'].items()}


def get_deck_name_for_note(note):
    if note.get("deckName"):
        return note["deckName"]

    card_ids = note.get("cards", [])
    if not card_ids:
        return None

    cards_info = invoke("cardsInfo", cards=[card_ids[0]])
    if cards_info.get("error") or not cards_info.get("result"):
        return None

    return cards_info["result"][0].get("deckName")


for note in notes_info["result"]:
    note_id = note["noteId"]
    original_cloze = note["fields"]["Cloze"]["value"]
    lemma_value = note["fields"]["Lemma"]["value"]
    definition = note["fields"]["Notes"]["value"]

    lemmas = split_lemmas(lemma_value)

    if len(lemmas) <= 1:
        lemma = lemmas[0] if lemmas else lemma_value.strip()
        new_cloze = make_cloze_for_lemma(original_cloze, lemma, definition)
        invoke(
            "updateNoteFields",
            note={
                "id": note_id,
                "fields": {
                    "Lemma": lemma,
                    "Subtitle": original_cloze,
                    "Cloze": new_cloze,
                },
            },
        )
        continue

    # Keep first lemma on original note.
    first_lemma = lemmas[0]
    first_cloze = make_cloze_for_lemma(original_cloze, first_lemma, definition)
    invoke(
        "updateNoteFields",
        note={
            "id": note_id,
            "fields": {
                "Lemma": first_lemma,
                "Subtitle": original_cloze,
                "Cloze": first_cloze,
            },
        },
    )

    # Clone one new note per extra lemma.
    base_fields = get_note_fields(note)
    deck_name = get_deck_name_for_note(note)
    if not deck_name:
        print(f"Could not determine deck for note {note_id}; skipping clones")
        continue

    for extra_lemma in lemmas[1:]:
        cloned_fields = dict(base_fields)
        cloned_fields["Lemma"] = extra_lemma
        cloned_fields["Subtitle"] = original_cloze
        cloned_fields["Cloze"] = make_cloze_for_lemma(original_cloze, extra_lemma, definition)

        result = invoke(
            "addNote",
            note={
                "deckName": deck_name,
                "modelName": note["modelName"],
                "fields": cloned_fields,
                "tags": note.get("tags", []),
            },
        )
        if result.get("error"):
            print(f"Failed to clone note {note_id} for lemma '{extra_lemma}': {result['error']}")
        else:
            print(f"Created note {result['result']} from note {note_id} for lemma '{extra_lemma}'")

# %%
# AI DEFINITION UPDATE FOR TAGGED NOTES
# Updates definition text for notes tagged: two_words_in_furigana_field
# Provider options:
# - provider = "openai"  (requires OPENAI_API_KEY)
# - provider = "ollama"  (free/local, requires Ollama running)

import os
import json
import requests

provider = "ollama"            # "openai" or "ollama"
openai_model = "gpt-4o-mini"
ollama_model = "qwen2.5:7b"    # change if needed, e.g. "llama3.1:8b"
dry_run = True                  # set False to write updates to Anki
limit = 50                      # max notes to process this run

TARGET_TAG = "two_words_in_furigana_field"


def ai_rewrite_definition(old_definition, lemma, furigana, cloze, notes_field, word_definition):
    prompt = f"""You are improving Japanese vocabulary flashcard definitions.

Return only one concise definition sentence/line.
Keep the meaning accurate and learner-friendly.
If old definition is already good, lightly clean it.
Do not include markdown, bullets, or explanations.

Lemma: {lemma}
Furigana: {furigana}
Cloze sentence: {cloze}
Old definition: {old_definition}
Notes field: {notes_field}
Word Definition field: {word_definition}
"""

    if provider == "openai":
        api_key = os.environ.get("OPENAI_API_KEY")
        if not api_key:
            raise RuntimeError("OPENAI_API_KEY is not set")

        r = requests.post(
            "https://api.openai.com/v1/chat/completions",
            headers={
                "Authorization": f"Bearer {api_key}",
                "Content-Type": "application/json",
            },
            json={
                "model": openai_model,
                "messages": [
                    {"role": "system", "content": "Rewrite definitions clearly and briefly."},
                    {"role": "user", "content": prompt},
                ],
                "temperature": 0.2,
            },
            timeout=60,
        )
        r.raise_for_status()
        data = r.json()
        return data["choices"][0]["message"]["content"].strip()

    if provider == "ollama":
        r = requests.post(
            "http://localhost:11434/api/generate",
            json={
                "model": ollama_model,
                "prompt": prompt,
                "stream": False,
                "options": {"temperature": 0.2},
            },
            timeout=120,
        )
        r.raise_for_status()
        data = r.json()
        return data.get("response", "").strip()

    raise ValueError(f"Unknown provider: {provider}")


note_ids = invoke("findNotes", query=f'tag:{TARGET_TAG}')
if note_ids.get("error"):
    raise RuntimeError(note_ids["error"])

ids = note_ids.get("result", [])[:limit]
print(f"Found {len(note_ids.get('result', []))} notes with tag '{TARGET_TAG}'. Processing {len(ids)}.")

if not ids:
    print("No notes to process.")
else:
    notes_info = invoke("notesInfo", notes=ids)
    if notes_info.get("error"):
        raise RuntimeError(notes_info["error"])

    updated = 0
    skipped = 0

    for note in notes_info.get("result", []):
        note_id = note["noteId"]
        fields = note.get("fields", {})

        lemma = fields.get("Lemma", {}).get("value", "").strip()
        furigana = fields.get("Furigana", {}).get("value", "").strip()
        cloze = fields.get("Cloze", {}).get("value", "").strip()
        notes_field = fields.get("Notes", {}).get("value", "").strip()
        word_definition = fields.get("Word Definition", {}).get("value", "").strip()

        # Prefer Notes as target; fallback to Word Definition if Notes missing.
        if "Notes" in fields:
            target_field = "Notes"
            old_definition = notes_field
        elif "Word Definition" in fields:
            target_field = "Word Definition"
            old_definition = word_definition
        else:
            print(f"Skip {note_id}: no Notes/Word Definition field")
            skipped += 1
            continue

        try:
            new_definition = ai_rewrite_definition(
                old_definition=old_definition,
                lemma=lemma,
                furigana=furigana,
                cloze=cloze,
                notes_field=notes_field,
                word_definition=word_definition,
            )
        except Exception as e:
            print(f"Skip {note_id}: AI call failed -> {e}")
            skipped += 1
            continue

        if not new_definition or new_definition == old_definition:
            print(f"No change {note_id}")
            skipped += 1
            continue

        print(f"Update {note_id} ({target_field})")
        print(f"  OLD: {old_definition[:120]}")
        print(f"  NEW: {new_definition[:120]}")

        if not dry_run:
            res = invoke(
                "updateNoteFields",
                note={
                    "id": note_id,
                    "fields": {target_field: new_definition},
                },
            )
            if res.get("error"):
                print(f"  Failed update {note_id}: {res['error']}")
                skipped += 1
                continue

        updated += 1

    print(json.dumps({"updated": updated, "skipped": skipped, "dry_run": dry_run}, ensure_ascii=False))

# %% [markdown]
# # query all the notes in the first love deck, which have an empty lemma field.
# # put everything inside 'Word Definition' into 'Notes'#
# # extract 'Lemma' and 'Word Definition' from the cloze (cloze looks like this “人生は{{c1::まるで::as if, quite}} ジグソーパズルだ”と)

# %%
#!/usr/bin/env python3
import json
import re
import urllib.request

ANKI_CONNECT_URL = "http://localhost:8765"
DECK_NAME = "Japanese Media::Filme & Serien::FirstLove"  # change if needed
DRY_RUN = True  # set to False to write changes

# Matches: {{c1::まるで::as if, quite}}
CLOZE_RE = re.compile(r"\{\{c\d+::(.*?)(?:::([^}]*))?\}\}", re.DOTALL)


def invoke(action, **params):
    payload = {"action": action, "version": 6, "params": params}
    req = urllib.request.Request(
        ANKI_CONNECT_URL,
        data=json.dumps(payload).encode("utf-8"),
        headers={"Content-Type": "application/json"},
    )
    with urllib.request.urlopen(req) as resp:
        data = json.loads(resp.read().decode("utf-8"))
    if data.get("error"):
        raise RuntimeError(f"AnkiConnect error ({action}): {data['error']}")
    return data["result"]


def merge_notes_with_word_definition(notes_val: str, word_def_val: str) -> str:
    notes_val = (notes_val or "").strip()
    word_def_val = (word_def_val or "").strip()

    if not word_def_val:
        return notes_val
    if not notes_val:
        return word_def_val
    if word_def_val in notes_val:
        return notes_val
    return f"{notes_val}<br>{word_def_val}"


def extract_from_cloze(cloze_text: str):
    if not cloze_text:
        return None, None
    m = CLOZE_RE.search(cloze_text)
    if not m:
        return None, None
    lemma = (m.group(1) or "").strip()
    definition = (m.group(2) or "").strip()
    return lemma, definition


def main():
    query = f'deck:"{DECK_NAME}" "Lemma:"'
    note_ids = invoke("findNotes", query=query)
    print(f"Found {len(note_ids)} notes with empty Lemma in deck: {DECK_NAME}")

    if not note_ids:
        return

    notes_info = invoke("notesInfo", notes=note_ids)

    updated = 0
    skipped = 0

    for note in notes_info:
        nid = note["noteId"]
        fields = note.get("fields", {})

        cloze_val = fields.get("Cloze", {}).get("value", "")
        old_word_def = fields.get("Word Definition", {}).get("value", "")
        old_notes = fields.get("Notes", {}).get("value", "")

        new_notes = merge_notes_with_word_definition(old_notes, old_word_def)
        new_lemma, new_word_def = extract_from_cloze(cloze_val)

        if not new_lemma and not new_word_def and new_notes == old_notes:
            skipped += 1
            print(f"Skip {nid}: no cloze extraction and no Notes update")
            continue

        update_fields = {}
        if new_notes != old_notes:
            update_fields["Notes"] = new_notes
        if new_lemma:
            update_fields["Lemma"] = new_lemma
        if new_word_def is not None:
            update_fields["Word Definition"] = new_word_def  # may become empty string

        if not update_fields:
            skipped += 1
            print(f"Skip {nid}: nothing to update")
            continue

        print(f"Update {nid}: {list(update_fields.keys())}")
        if not DRY_RUN:
            invoke("updateNoteFields", note={"id": nid, "fields": update_fields})
        updated += 1

    print(f"Done. Updated: {updated}, Skipped: {skipped}, Dry run: {DRY_RUN}")


if __name__ == "__main__":
    main()
# Out:
# Found 454 notes with empty Lemma in deck: Japanese Media::Filme & Serien::FirstLove
# Update 1734510465438: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465439: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465448: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465451: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465453: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465454: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465455: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465456: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465457: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465459: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465460: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465466: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465467: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465468: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465473: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465474: ['Lemma', 'Word Definition']
# Update 1734510465479: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465480: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465485: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465487: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465488: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465495: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465496: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465498: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465503: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465506: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465507: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465509: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465510: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465514: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465516: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465517: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465518: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465522: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465523: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465526: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465530: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465532: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465533: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465543: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465544: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465548: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465549: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465554: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465559: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465560: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465562: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465566: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465568: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465572: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465573: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465579: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465581: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465583: ['Notes']
# Update 1734510465586: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465588: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465600: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465602: ['Notes', 'Lemma', 'Word Definition']
# Update 1734510465606: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383240: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383242: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383243: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383244: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383245: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383246: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383247: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383248: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383249: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383250: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383251: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383252: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383253: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383256: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383257: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383258: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383259: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383260: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383261: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383262: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383263: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383265: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383266: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383268: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383269: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383270: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383273: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383274: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383275: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383276: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383277: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383279: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383280: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383283: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383284: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383285: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383286: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383291: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383292: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383293: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383295: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383296: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383297: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383299: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383300: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383301: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383303: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383304: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383305: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383306: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383307: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383308: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383309: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383311: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383312: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383313: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383314: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383315: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383316: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383317: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383318: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383319: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383321: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383322: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383323: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383326: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383329: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383330: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383331: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383333: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383335: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383337: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383339: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383340: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383341: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383342: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383343: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383344: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383347: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383348: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383349: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383350: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383351: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383353: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383354: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383356: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383357: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383358: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383359: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383360: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383362: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383364: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383365: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383366: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383367: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383368: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383370: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383372: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383373: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383374: ['Lemma', 'Word Definition']
# Update 1734593383376: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383377: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383378: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383379: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383380: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383381: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383382: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383383: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383384: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383385: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383386: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383388: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383389: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383390: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383391: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383392: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383393: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383395: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383398: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383404: ['Notes', 'Lemma', 'Word Definition']
# Update 1734593383405: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071284: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071286: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071287: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071288: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071289: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071290: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071291: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071292: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071293: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071294: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071295: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071296: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071297: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071299: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071300: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071301: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071302: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071303: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071305: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071307: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071308: ['Lemma', 'Word Definition']
# Update 1734681071309: ['Lemma', 'Word Definition']
# Update 1734681071310: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071311: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071312: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071313: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071314: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071315: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071316: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071318: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071319: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071320: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071325: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071327: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071328: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071329: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071330: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071335: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071340: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071344: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071347: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071350: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071351: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071354: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071355: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071358: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071364: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071366: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071369: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071370: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071371: ['Notes']
# Update 1734681071372: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071373: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071374: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071375: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071376: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071377: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071378: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071379: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071380: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071381: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071382: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071383: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071384: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071385: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071386: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071387: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071388: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071389: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071390: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071391: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071392: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071393: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071397: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071398: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071399: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071400: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071401: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071402: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071403: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071404: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071405: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071407: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071409: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071410: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071412: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071413: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071414: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071415: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071416: ['Notes']
# Update 1734681071417: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071418: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071419: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071420: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071422: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071423: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071424: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071425: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071426: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071428: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071429: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071431: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071432: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071433: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071434: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071435: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071436: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071437: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071439: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071440: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071441: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071444: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071445: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071446: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071447: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071448: ['Notes', 'Lemma', 'Word Definition']
# Update 1734681071449: ['Notes', 'Lemma', 'Word Definition']
# Skip 1734681071450: no cloze extraction and no Notes update
# Update 1734681071451: ['Lemma', 'Word Definition']
# Skip 1739865122051: no cloze extraction and no Notes update
# Skip 1739865122055: no cloze extraction and no Notes update
# Update 1739865122056: ['Lemma', 'Word Definition']
# Update 1739865122057: ['Lemma', 'Word Definition']
# Update 1739865122058: ['Lemma', 'Word Definition']
# Update 1739865122059: ['Lemma', 'Word Definition']
# Update 1739865122060: ['Lemma', 'Word Definition']
# Skip 1739865122061: no cloze extraction and no Notes update
# Update 1739865122062: ['Lemma', 'Word Definition']
# Update 1739865122063: ['Lemma', 'Word Definition']
# Skip 1739865122064: no cloze extraction and no Notes update
# Skip 1739865122065: no cloze extraction and no Notes update
# Skip 1739865122066: no cloze extraction and no Notes update
# Update 1739865122067: ['Lemma', 'Word Definition']
# Update 1739865122068: ['Lemma', 'Word Definition']
# Update 1739865122069: ['Lemma', 'Word Definition']
# Update 1739865122070: ['Lemma', 'Word Definition']
# Skip 1739865122071: no cloze extraction and no Notes update
# Update 1739865122072: ['Lemma', 'Word Definition']
# Update 1739865122073: ['Lemma', 'Word Definition']
# Update 1739865122074: ['Lemma', 'Word Definition']
# Skip 1739865122075: no cloze extraction and no Notes update
# Update 1739865122076: ['Lemma', 'Word Definition']
# Update 1739865122077: ['Lemma', 'Word Definition']
# Update 1739865122078: ['Lemma', 'Word Definition']
# Update 1739865122079: ['Lemma', 'Word Definition']
# Skip 1739865122080: no cloze extraction and no Notes update
# Skip 1739865122081: no cloze extraction and no Notes update
# Skip 1739865122082: no cloze extraction and no Notes update
# Update 1739865122083: ['Lemma', 'Word Definition']
# Update 1739865122084: ['Lemma', 'Word Definition']
# Update 1739865122085: ['Lemma', 'Word Definition']
# Update 1739865122086: ['Lemma', 'Word Definition']
# Update 1739865122087: ['Lemma', 'Word Definition']
# Update 1739865122088: ['Lemma', 'Word Definition']
# Update 1739865122089: ['Lemma', 'Word Definition']
# Update 1739865122090: ['Lemma', 'Word Definition']
# Update 1739865122091: ['Lemma', 'Word Definition']
# Update 1739865122092: ['Lemma', 'Word Definition']
# Skip 1739865122093: no cloze extraction and no Notes update
# Update 1739865122094: ['Lemma', 'Word Definition']
# Update 1739865122095: ['Lemma', 'Word Definition']
# Update 1739865122096: ['Lemma', 'Word Definition']
# Update 1739865122097: ['Lemma', 'Word Definition']
# Update 1739865122098: ['Lemma', 'Word Definition']
# Skip 1739865122099: no cloze extraction and no Notes update
# Update 1739865122100: ['Lemma', 'Word Definition']
# Update 1739865122101: ['Lemma', 'Word Definition']
# Update 1739865122102: ['Lemma', 'Word Definition']
# Update 1739865122103: ['Lemma', 'Word Definition']
# Update 1739865122104: ['Lemma', 'Word Definition']
# Update 1739865122105: ['Lemma', 'Word Definition']
# Update 1739865122106: ['Lemma', 'Word Definition']
# Update 1739865122107: ['Lemma', 'Word Definition']
# Update 1739865122108: ['Lemma', 'Word Definition']
# Update 1739865122109: ['Lemma', 'Word Definition']
# Update 1739865122110: ['Lemma', 'Word Definition']
# Update 1739865122111: ['Lemma', 'Word Definition']
# Update 1739865122112: ['Lemma', 'Word Definition']
# Update 1739865122113: ['Lemma', 'Word Definition']
# Update 1739865122114: ['Lemma', 'Word Definition']
# Update 1739865122115: ['Lemma', 'Word Definition']
# Skip 1739865122116: no cloze extraction and no Notes update
# Update 1739865122117: ['Lemma', 'Word Definition']
# Update 1739865122118: ['Lemma', 'Word Definition']
# Update 1739865122119: ['Lemma', 'Word Definition']
# Update 1739865122120: ['Lemma', 'Word Definition']
# Update 1739865122121: ['Lemma', 'Word Definition']
# Update 1739865122122: ['Lemma', 'Word Definition']
# Update 1739865122123: ['Lemma', 'Word Definition']
# Skip 1739865122124: no cloze extraction and no Notes update
# Update 1739865122125: ['Lemma', 'Word Definition']
# Update 1739865122126: ['Lemma', 'Word Definition']
# Update 1739865122127: ['Lemma', 'Word Definition']
# Skip 1739865122128: no cloze extraction and no Notes update
# Update 1739865122129: ['Lemma', 'Word Definition']
# Update 1739865122130: ['Lemma', 'Word Definition']
# Update 1739865122131: ['Lemma', 'Word Definition']
# Update 1739865122132: ['Lemma', 'Word Definition']
# Skip 1739865122133: no cloze extraction and no Notes update
# Skip 1739865122134: no cloze extraction and no Notes update
# Update 1739865122135: ['Lemma', 'Word Definition']
# Update 1739865122136: ['Lemma', 'Word Definition']
# Update 1739865122137: ['Lemma', 'Word Definition']
# Update 1739865122138: ['Lemma', 'Word Definition']
# Update 1739865122139: ['Lemma', 'Word Definition']
# Skip 1739865122140: no cloze extraction and no Notes update
# Update 1739865122141: ['Lemma', 'Word Definition']
# Skip 1739865122142: no cloze extraction and no Notes update
# Update 1739865122143: ['Lemma', 'Word Definition']
# Update 1739865122144: ['Lemma', 'Word Definition']
# Update 1739865122145: ['Lemma', 'Word Definition']
# Update 1739865122146: ['Lemma', 'Word Definition']
# Update 1739865122147: ['Lemma', 'Word Definition']
# Update 1739865122148: ['Lemma', 'Word Definition']
# Update 1739865122149: ['Lemma', 'Word Definition']
# Update 1739865122150: ['Lemma', 'Word Definition']
# Update 1739865122151: ['Lemma', 'Word Definition']
# Skip 1739865122152: no cloze extraction and no Notes update
# Update 1739865122153: ['Lemma', 'Word Definition']
# Update 1739865122154: ['Lemma', 'Word Definition']
# Update 1739865122155: ['Lemma', 'Word Definition']
# Update 1739865122156: ['Lemma', 'Word Definition']
# Update 1739865122157: ['Lemma', 'Word Definition']
# Update 1739865122158: ['Lemma', 'Word Definition']
# Update 1739865122159: ['Lemma', 'Word Definition']
# Update 1739865122160: ['Lemma', 'Word Definition']
# Update 1739865122161: ['Lemma', 'Word Definition']
# Update 1739865122162: ['Lemma', 'Word Definition']
# Update 1739865122163: ['Lemma', 'Word Definition']
# Update 1739865122164: ['Lemma', 'Word Definition']
# Update 1739865122165: ['Lemma', 'Word Definition']
# Update 1739865122166: ['Lemma', 'Word Definition']
# Update 1739865122167: ['Lemma', 'Word Definition']
# Update 1739865122168: ['Lemma', 'Word Definition']
# Update 1739865122169: ['Lemma', 'Word Definition']
# Update 1739865122170: ['Lemma', 'Word Definition']
# Update 1739865122171: ['Lemma', 'Word Definition']
# Update 1739865122172: ['Lemma', 'Word Definition']
# Update 1739865122173: ['Lemma', 'Word Definition']
# Skip 1739865122174: no cloze extraction and no Notes update
# Update 1739865122175: ['Lemma', 'Word Definition']
# Update 1739865122176: ['Lemma', 'Word Definition']
# Update 1739865122177: ['Lemma', 'Word Definition']
# Update 1739865122178: ['Lemma', 'Word Definition']
# Update 1739865122179: ['Lemma', 'Word Definition']
# Update 1739865122180: ['Lemma', 'Word Definition']
# Update 1739865122181: ['Lemma', 'Word Definition']
# Update 1739865122182: ['Lemma', 'Word Definition']
# Update 1739865122183: ['Lemma', 'Word Definition']
# Update 1739865122184: ['Lemma', 'Word Definition']
# Update 1739865122185: ['Lemma', 'Word Definition']
# Update 1739865122186: ['Lemma', 'Word Definition']
# Update 1739865122187: ['Lemma', 'Word Definition']
# Skip 1739865122188: no cloze extraction and no Notes update
# Update 1739865122189: ['Lemma', 'Word Definition']
# Update 1739865122190: ['Lemma', 'Word Definition']
# Update 1739865122191: ['Lemma', 'Word Definition']
# Update 1739865122192: ['Lemma', 'Word Definition']
# Update 1739865122193: ['Lemma', 'Word Definition']
# Update 1739865122194: ['Lemma', 'Word Definition']
# Update 1739865122195: ['Lemma', 'Word Definition']
# Update 1739865122196: ['Lemma', 'Word Definition']
# Update 1739865122197: ['Lemma', 'Word Definition']
# Update 1739865122198: ['Lemma', 'Word Definition']
# Skip 1739865122199: no cloze extraction and no Notes update
# Update 1739865122200: ['Lemma', 'Word Definition']
# Update 1739865122201: ['Lemma', 'Word Definition']
# Skip 1739865122202: no cloze extraction and no Notes update
# Skip 1739865122203: no cloze extraction and no Notes update
# Update 1739865122204: ['Lemma', 'Word Definition']
# Skip 1739865122205: no cloze extraction and no Notes update
# Skip 1739865122206: no cloze extraction and no Notes update
# Skip 1739865122207: no cloze extraction and no Notes update
# Skip 1739865122208: no cloze extraction and no Notes update
# Done. Updated: 423, Skipped: 31, Dry run: True
